# %%
code_name = pd.read_csv("../raw_data/codename.csv", header=None, encoding="utf-8")

# %%
code_name.columns= ['code','code_name']
code_name
# Out:
#         code code_name
# 0   CS100010   호프·간이주점
# 1   CS100001     한식음식점
# 2   CS100002     중식음식점
# 3   CS100003     일식음식점
# 4   CS100004     양식음식점
# 5   CS100005     분식전문점
# 6   CS100006    패스트푸드점
# 7   CS100007     치킨전문점
# 8   CS100008       제과점
# 9   CS100009     커피·음료
# 10  CS200001    일반교습학원
# 11  CS200002     외국어학원
# 12  CS200004      치과의원
# 13  CS200006      일반의원
# 14  CS200007    가전제품수리
# 15  CS200008    부동산중개업
# 16  CS200010       노래방
# 17  CS200013   세탁소(가정)
# 18  CS200014     스포츠클럽
# 19  CS200015  자동차수리·세차
# 20  CS200016     두발미용업
# 21  CS200017       네일숍
# 22  CS200018     피부관리실
# 23  CS300001      슈퍼마켓
# 24  CS300002       편의점
# 25  CS300003  컴퓨터·주변기기
# 26  CS300004       핸드폰
# 27  CS300005       식료품
# 28  CS300006    건강보조식품
# 29  CS300007       의류점
# 30  CS300008      패션용품
# 31  CS300009   의약·의료용품
# 32  CS300010     서적·문구
# 33  CS300011       화장품
# 34  CS300012     오락·운동
# 35  CS300013      섬유제품
# 36  CS300014     화초·애완
# 37  CS300015     가구·가전
# 38  CS300016   주방·가정용품
# ...

# %% [markdown]
# #### OLS Regression 결과
#
# ```
# coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# C(code)[CS100001]            3.2647      0.214     15.278      0.000       2.846       3.684
# C(code)[CS100002]           -0.3141      0.111     -2.827      0.005      -0.532      -0.096
# C(code)[CS100003]           -0.2275      0.143     -1.593      0.111      -0.508       0.053
# C(code)[CS100004]           -0.0930      0.114     -0.818      0.413      -0.316       0.130
# C(code)[CS100005]           -1.1309      0.118     -9.593      0.000      -1.362      -0.900
# C(code)[CS100006]           -0.2408      0.115     -2.086      0.037      -0.467      -0.014
# C(code)[CS100007]           -0.5803      0.154     -3.763      0.000      -0.883      -0.278
# C(code)[CS100008]           -0.0178      0.110     -0.161      0.872      -0.234       0.199
# C(code)[CS100009]           -1.0532      0.129     -8.151      0.000      -1.307      -0.800
# C(code)[CS100010]           -0.8637      0.209     -4.125      0.000      -1.274      -0.453
# C(code)[CS200001]            0.6060      0.122      4.964      0.000       0.367       0.845
# C(code)[CS200002]            0.2070      0.117      1.772      0.077      -0.022       0.436
# C(code)[CS200003]           -0.5192      0.123     -4.238      0.000      -0.759      -0.279
# C(code)[CS200004]            0.8986      0.117      7.669      0.000       0.669       1.128
# C(code)[CS200005]            0.2631      0.107      2.462      0.014       0.054       0.473
# C(code)[CS200006]            1.2226      0.120     10.194      0.000       0.987       1.458
# C(code)[CS200007]            0.1435      0.109      1.315      0.189      -0.071       0.357
# C(code)[CS200008]           -0.2495      0.159     -1.570      0.117      -0.561       0.062
# C(code)[CS200009]           -0.3418      0.149     -2.301      0.021      -0.633      -0.050
# C(code)[CS200010]           -0.7816      0.268     -2.913      0.004      -1.308      -0.255
# C(code)[CS200011]           -0.1682      0.150     -1.122      0.262      -0.462       0.126
# C(code)[CS200012]           -0.6237      0.161     -3.884      0.000      -0.939      -0.309
# C(code)[CS200013]           -0.4667      0.098     -4.764      0.000      -0.659      -0.275
# C(code)[CS200014]           -0.1340      0.117     -1.145      0.252      -0.364       0.096
# C(code)[CS200015]            0.2030      0.109      1.863      0.063      -0.011       0.417
# C(code)[CS200016]           -1.1126      0.128     -8.702      0.000      -1.363      -0.862
# C(code)[CS200017]           -0.2370      0.125     -1.897      0.058      -0.482       0.008
# C(code)[CS200018]           -0.4663      0.113     -4.118      0.000      -0.688      -0.244
# C(code)[CS300001]            2.8416      0.115     24.626      0.000       2.615       3.068
# C(code)[CS300002]            3.3262      0.127     26.205      0.000       3.077       3.575
# C(code)[CS300003]            0.1007      0.110      0.912      0.362      -0.116       0.317
# C(code)[CS300004]           -0.1502      0.104     -1.448      0.148      -0.354       0.053
# C(code)[CS300005]            0.2919      0.111      2.625      0.009       0.074       0.510
# C(code)[CS300006]            0.1398      0.109      1.283      0.200      -0.074       0.353
# C(code)[CS300007]           -0.4813      0.120     -4.000      0.000      -0.717      -0.245
# C(code)[CS300008]           -0.0869      0.103     -0.843      0.399      -0.289       0.115
# C(code)[CS300009]            1.5862      0.109     14.614      0.000       1.373       1.799
# C(code)[CS300010]            0.0390      0.106      0.369      0.712      -0.168       0.246
# C(code)[CS300011]           -0.8848      0.112     -7.903      0.000      -1.104      -0.665
# C(code)[CS300012]            0.1895      0.108      1.760      0.079      -0.022       0.401
# C(code)[CS300013]           -0.1457      0.100     -1.456      0.146      -0.342       0.051
# C(code)[CS300014]           -0.4206      0.112     -3.765      0.000      -0.640      -0.202
# C(code)[CS300015]            0.8362      0.107      7.782      0.000       0.625       1.047
# C(code)[CS300016]           -0.2915      0.125     -2.334      0.020      -0.536      -0.047
# C(code)[CS300017]            0.0051      0.110      0.046      0.963      -0.211       0.221
# s_store_no_of_store          0.0793      0.026      3.026      0.003       0.028       0.131
# s_store_no_of_opening        0.1190      0.029      4.169      0.000       0.063       0.175
# s_store_no_of_closing        0.2963      0.026     11.552      0.000       0.246       0.347
# s_work_female                0.2477      0.023     10.953      0.000       0.203       0.292
# s_float_male                 0.5725      0.136      4.206      0.000       0.306       0.839
# s_float_female              -0.2945      0.140     -2.108      0.035      -0.568      -0.020
# b_facil_total                0.0118      0.018      0.640      0.523      -0.024       0.048
# b_apt_avg_price              0.0167      0.020      0.841      0.400      -0.022       0.056
# b_income_avg_monthly_inc    -0.0256      0.031     -0.826      0.409      -0.087       0.035
# sales_weekday               -0.0990      0.034     -2.874      0.004      -0.167      -0.031
# sales_female                -0.0412      0.045     -0.924      0.356      -0.129       0.046
# sales_2030s                  0.0409      0.040      1.014      0.311      -0.038       0.120
# sales_06_11                  0.0512      0.064      0.803      0.422      -0.074       0.176
# sales_11_14                  0.0917      0.078      1.181      0.238      -0.061       0.244
# sales_14_17                  0.0989      0.098      1.009      0.313      -0.093       0.291
# sales_17_21                  0.0919      0.088      1.049      0.294      -0.080       0.264
# sales_21_24                  0.2105      0.113      1.870      0.062      -0.010       0.431
#
# ```

# %% [markdown]
# ## 업종별 매출액 순위를 알아보자

# %%
df_before_groupby = pd.read_csv("../raw_data/df_before_emb.csv", encoding="euc-kr")

# %%
[i for i in df_before_groupby.columns if "sales" in i]
# Out:
# ['sales_weekday_amt',
#  'sales_female_amt',
#  'sales_2030s_amt',
#  'sales_06_11_amt',
#  'sales_11_14_amt',
#  'sales_14_17_amt',
#  'sales_17_21_amt',
#  'sales_21_24_amt',
#  'sales_total']

# %%
code_mean=df_before_groupby[['code','sales_total']].groupby(by=['code'], as_index=False).mean()

# %%
code_mean = pd.merge(code_mean,code_name, on=['code'])

# %%
code_desc=code_mean.sort_values(["sales_total"], ascending=[False])
code_desc.index =pd.RangeIndex(start=1, stop=41, step=1)
code_desc
# Out:
#         code   sales_total code_name
# 1   CS100001  9.362905e+08     한식음식점
# 2   CS300002  5.945375e+08       편의점
# 3   CS300001  5.681429e+08      슈퍼마켓
# 4   CS300015  5.086577e+08     가구·가전
# 5   CS200006  3.986216e+08      일반의원
# 6   CS300009  3.830208e+08   의약·의료용품
# 7   CS200001  2.763756e+08    일반교습학원
# 8   CS200004  2.756502e+08      치과의원
# 9   CS100004  2.680809e+08     양식음식점
# 10  CS300017  2.632885e+08     통신판매업
# 11  CS300005  2.598116e+08       식료품
# 12  CS100010  2.508869e+08   호프·간이주점
# 13  CS300012  2.269457e+08     오락·운동
# 14  CS300007  2.016887e+08       의류점
# 15  CS100003  1.783506e+08     일식음식점
# 16  CS200002  1.717183e+08     외국어학원
# 17  CS100008  1.697850e+08       제과점
# 18  CS200015  1.691264e+08  자동차수리·세차
# 19  CS100009  1.670301e+08     커피·음료
# 20  CS100002  1.544733e+08     중식음식점
# 21  CS200008  1.479785e+08    부동산중개업
# 22  CS300011  1.311069e+08       화장품
# 23  CS100006  1.310893e+08    패스트푸드점
# 24  CS100007  1.302598e+08     치킨전문점
# ...

# %%
code_asc=code_mean.sort_values(["sales_total"], ascending=[True])
code_asc.index =pd.RangeIndex(start=1, stop=41, step=1)
code_asc
# Out:
#         code   sales_total code_name
# 1   CS200017  2.231267e+07       네일숍
# 2   CS200013  2.758632e+07   세탁소(가정)
# 3   CS200018  3.084115e+07     피부관리실
# 4   CS300014  4.757965e+07     화초·애완
# 5   CS200007  5.276175e+07    가전제품수리
# 6   CS300013  6.869225e+07      섬유제품
# 7   CS300004  7.470858e+07       핸드폰
# 8   CS300003  7.956408e+07  컴퓨터·주변기기
# 9   CS200010  8.791876e+07       노래방
# 10  CS200016  1.018016e+08     두발미용업
# 11  CS200014  1.087405e+08     스포츠클럽
# 12  CS300016  1.123937e+08   주방·가정용품
# 13  CS300006  1.174831e+08    건강보조식품
# 14  CS300008  1.216531e+08      패션용품
# 15  CS300010  1.242372e+08     서적·문구
# 16  CS100005  1.299086e+08     분식전문점
# 17  CS100007  1.302598e+08     치킨전문점
# 18  CS100006  1.310893e+08    패스트푸드점
# 19  CS300011  1.311069e+08       화장품
# 20  CS200008  1.479785e+08    부동산중개업
# 21  CS100002  1.544733e+08     중식음식점
# 22  CS100009  1.670301e+08     커피·음료
# 23  CS200015  1.691264e+08  자동차수리·세차
# 24  CS100008  1.697850e+08       제과점
# ...
